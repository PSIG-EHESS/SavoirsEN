# %%
import os
import glob
from nervaluate import Evaluator
import argparse
from tabulate import tabulate


'''
Ce script utilise nervaluate pour calculer la précision et le rappel
du marquage automatique des entités nommées par rapport à un étalon-or. 
Il recherche un dossier appelé "Predictions", qui doit contenir tous les fichiers à évaluer sous la forme suivante:
TOKEN   NE-COARSE-LIT   GOLD   VALIDITY
Deux       O             O        1
mois       O             O        1
...
Les scores sont générés pour chaque fichier et enregistrés dans un dossier appelé "Scores".
'''

# Initialize the parser
parser = argparse.ArgumentParser(description="utilise nervaluate pour calculer la précision et le rappel" )

def pretty_print(result, outfile=None):
    """Affichage plus beau que par défaut"""
    x_name = ['Measure'] + [k for k in result]
    y_name = []
    rows = []
    for evaluation in result:
        print(evaluation)
        metrics = result[evaluation]
        row = []
        for metric, score in metrics.items():
            if metric not in y_name:
                y_name.append(metric)
            row.append(round(score, 3)) # Arrondir
        rows.append(row)
    grid = [score for score in [column for column in zip(*rows)]]
    print(*x_name, sep='\t', file=outfile)
    for i, row in enumerate(grid):
        print(y_name[i], *map(str, row), sep='\t', file=outfile)
        
        
for input_file in glob.iglob("db_results/SpaCy_prediction/prediction_BERT/*"):
    '''Passez en boucle dans le dossier "Prédictions"'''
    st_annotation = []
    gold_annotation = []
    # load the predictions and gold standard tags
    with open(input_file, 'r', encoding='utf-8') as fin:
        for line in fin:
            line = line.strip()
            if not line:
                continue
            try:
                #print(line)
                token, automatique, gold, validity = line.split('\t') 
                #print(token)
            except ValueError:
                print(line)
            automatique = automatique.upper()
            # begin formatting the tags in the 'conll' format
            st_annotation.append(f"{token}\t{automatique}")
            gold_annotation.append(f"{token}\t{gold}")
    #finish 'conll' format
    true = '\n'.join(gold_annotation)
    pred_st = '\n'.join(st_annotation)
    #print(true)
    #print(pred_st)
   
    # OUTPUT
    # file_name to not loose the orginal information
    #output_file = "db_results/precision_rappel/LDSI_21_Celenza_precision_rappel.csv"


    # generate precision and recall report
    evaluator = Evaluator(true, pred_st, tags=['LOC', 'PER'], loader="conll")
    results, results_by_tag = evaluator.evaluate()
        
        
    # We can automatize it to do better
    # directory out
    output_dir = "db_results/SpaCy_precision_rappel/precision_rappel_BERT/"
    # new files out with original's name plus _text and its new format .txt
    results_file = "%s%s_precision_rappel.csv"%(output_dir, os.path.splitext(os.path.basename(input_file))[0])
    print(results_file)
    # save it as blabla_text.csv
    with open(results_file, 'w', encoding="utf-8") as fpout: 
        pretty_print(results, outfile=fpout)
        #print to verify the result
        #print(first)
# Out:
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_01_Didier_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_02_Colin_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_03_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_04_Gfrereis_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_05_Dege_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_06_Therstappen_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_07_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_08_PoncerGuedron_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_09_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_10_Bon_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_11_Bert_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_12_Bigg_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_13_Mathis_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_14_Canfora_a_voir_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_15_Mohnike_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_16_Grage_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/BNU_17_Ochsner_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_11_2018_Calame_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_11_2018_Dupont_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_11_2018_introduction_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_11_2018_Longhi_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_11_2018_Saint-Martin_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_11_2018_Wersinger_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_8_Buccheri_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_8_Caillaud_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_8_Davieau_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_8_Introduction_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_8_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/CMA_8_Mahieu_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_01_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_02_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_03_Fabiani_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_04_Dugast_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_06_Elman_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_07_Jacob_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_08_Glassner_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_09_Delatour_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_10_Herrou_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_11_Chatelain_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_12_Guerin_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_13_Durand_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_14_Icher_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_15_Stroumsa_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_16_KochPiettre_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_17_Poirel_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_18_Tillman_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_19_Faure_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_20_Houdart_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_21_Celenza_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSI_24_Mandressi_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_01_Jacob_Introduction_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_02_Jacob_LelogeMainPensee_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_03_Liberski_DevinsKasena_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_04_Icher_LesOutilsDuCompagnon_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_05_Samson_LaMainEtLoutil_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_06_Campos_GesteMusicalPiano_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_07_Brives_LobservationAuMicroscope_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_08_Fraenkel_LinsaisissableTableAEcrire_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_09_Icher_LetabliDuMenuisier_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_10_Schneider_LaTableDuLettreChinois_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_11_Chatelain_LesGardoiresDuLettre_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_12_BeaudoinLafon_TablesInformatiques_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_13_Jacob_ManipulerManier_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_14_Glassner_DissectionMe_sopotamie_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_15_Schnapp_TerrainAntiquaireArche_ologue_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_16_Lacour_AdministrationChosesNaturelles_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_17_Benazera_LaRechercheIntelligenceExtraterrestre_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_18_Mandressi_GestesFormesEcritureSavante_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_19_Ragazzoli_LireInscrireSurvivreEgypteAncienne_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_20_Jolly_NotesTerrainMarcelGriaule_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_21_DacosMounier_LesCarnetsDeRecherche_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_22_Bustarret_Coupercoller_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_23_Chatelain_RaisonsDecrire_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_26_Escande_LeGesteCalligraphiqueChine_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_27_Dejean_LaStructurationDocumentsElectroniques_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_28_Lardet_UsagesArchives_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_29_Revel_ChantdelaMemoire_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_30_Colas_RelectureCorrectionManuscritsIndiens_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_31_Dorival_Hexaples_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_32_Blair_TablesIndex_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_33_Berra_Thesaurus_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_34_Besse_NatureFormesProductivite_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_35_Zucker_Catasterismes_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_36_Jacob_Cartographie_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_37_Mandressi_ImagesMedicales_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_38_Houdart_ArchitectureTrompeLoeil_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_39-2_Galewicz_MemoireOubli_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_40_Guerin_Tablette_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_42_Jacob_Cheminements_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_43_Deleage_Amerindien_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_44_Mendelsohn_Maladie_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_45_Jensen_Savoir_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_46_Jacob_RaisonsGraphiques_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_47_Narcy_Particule_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_48_Lackner_Chine_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_49_Andler_Math_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_50_Fabiani_SituationsExtremes_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
# db_results/SpaCy_precision_rappel/precision_rappel_BERT/LDSII_52_Kassow_OnegShabbes_text_SpaCy_bert_BIO_prediction_precision_rappel.csv
# ent_type
# partial
# strict
# exact
