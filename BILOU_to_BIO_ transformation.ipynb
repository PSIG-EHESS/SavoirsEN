# %% [markdown]
# # 1 - Step
# ## import the files from the directory

# %% [markdown]
# ## 1.a
# ### open the file into a variable

# %%
# operation system
import os
# regular expression
import re
# retrives file support
import glob
# inform the path
for file_path in glob.iglob('SpaCy_tok/SpaCy_sm/*.tsv'):
    #transform path into a readable file
    f_name = (file_path)
    #print(f_name)
    
    # open the variable to be read and split into words
    with open(f_name, 'r', encoding='utf8') as f:
        # read and split into words to count word in file
        text = f.read()
        #print(text)
        
    _replacements = {
            'B-ORG': 'O',
            'U-ORG': 'O',
            'I-ORG': 'O',
            'L-ORG': 'O',
            
            'B-MISC': 'O',
            'U-MISC': 'O',
            'I-MISC': 'O',
            'L-MISC': 'O',
            
            'U-PER': 'B-PER',
            'U-LOC': 'B-LOC',
            'L-PER': 'I-PER',
            'L-LOC': 'I-LOC',
            }

    def _do_replace(text):
        return _replacements.get(text.group(0))

    def replace_tags(text, _re=re.compile('|'.join(re.escape(r) for r in _replacements))):
        return _re.sub(_do_replace, text)

    result = (replace_tags(text))
    #print(result)
    
    # directory out
    output_dir = "SpaCy_BIO/SpaCy_sm_BIO/"
    # new files out with original's name plus _BIO and its new format .txt
    results_file = "%s%s_BIO.txt"%(output_dir, os.path.splitext(os.path.basename(f_name))[0])
    print(results_file)
    # save it as blabla_BIO.txt
    with open(results_file, 'w', encoding='utf8') as fpout: 
        fpout.write(str(result))
        #print to verify the result
        #print(first)
# Out:
# SpaCy_BIO/SpaCy_sm_BIO/BNU_01_Didier_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_02_Colin_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_03_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_04_Gfrereis_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_05_Dege_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_06_Therstappen_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_07_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_08_PoncerGuedron_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_09_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_10_Bon_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_11_Bert_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_12_Bigg_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_13_Mathis_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_14_Canfora_a_voir_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_15_Mohnike_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_16_Grage_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/BNU_17_Ochsner_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_11_2018_Calame_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_11_2018_Dupont_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_11_2018_introduction_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_11_2018_Longhi_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_11_2018_Saint-Martin_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_11_2018_Wersinger_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_8_Buccheri_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_8_Caillaud_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_8_Davieau_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_8_Introduction_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_8_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/CMA_8_Mahieu_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_01_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_02_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_03_Fabiani_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_04_Dugast_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_06_Elman_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_07_Jacob_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_08_Glassner_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_09_Delatour_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_10_Herrou_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_11_Chatelain_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_12_Guerin_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_13_Durand_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_14_Icher_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_15_Stroumsa_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_16_KochPiettre_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_17_Poirel_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_18_Tillman_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_19_Faure_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_20_Houdart_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_21_Celenza_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSI_24_Mandressi_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_01_Jacob_Introduction_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_02_Jacob_LelogeMainPensee_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_03_Liberski_DevinsKasena_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_04_Icher_LesOutilsDuCompagnon_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_05_Samson_LaMainEtLoutil_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_06_Campos_GesteMusicalPiano_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_07_Brives_LobservationAuMicroscope_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_08_Fraenkel_LinsaisissableTableAEcrire_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_09_Icher_LetabliDuMenuisier_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_10_Schneider_LaTableDuLettreChinois_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_11_Chatelain_LesGardoiresDuLettre_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_12_BeaudoinLafon_TablesInformatiques_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_13_Jacob_ManipulerManier_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_14_Glassner_DissectionMe_sopotamie_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_15_Schnapp_TerrainAntiquaireArche_ologue_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_16_Lacour_AdministrationChosesNaturelles_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_17_Benazera_LaRechercheIntelligenceExtraterrestre_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_18_Mandressi_GestesFormesEcritureSavante_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_19_Ragazzoli_LireInscrireSurvivreEgypteAncienne_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_20_Jolly_NotesTerrainMarcelGriaule_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_21_DacosMounier_LesCarnetsDeRecherche_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_22_Bustarret_Coupercoller_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_23_Chatelain_RaisonsDecrire_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_26_Escande_LeGesteCalligraphiqueChine_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_27_Dejean_LaStructurationDocumentsElectroniques_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_28_Lardet_UsagesArchives_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_29_Revel_ChantdelaMemoire_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_30_Colas_RelectureCorrectionManuscritsIndiens_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_31_Dorival_Hexaples_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_32_Blair_TablesIndex_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_33_Berra_Thesaurus_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_34_Besse_NatureFormesProductivite_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_35_Zucker_Catasterismes_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_36_Jacob_Cartographie_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_37_Mandressi_ImagesMedicales_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_38_Houdart_ArchitectureTrompeLoeil_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_39-2_Galewicz_MemoireOubli_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_40_Guerin_Tablette_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_42_Jacob_Cheminements_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_43_Deleage_Amerindien_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_44_Mendelsohn_Maladie_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_45_Jensen_Savoir_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_46_Jacob_RaisonsGraphiques_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_47_Narcy_Particule_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_48_Lackner_Chine_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_49_Andler_Math_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_50_Fabiani_SituationsExtremes_text_conll_SpaCy_sm_BIO.txt
# SpaCy_BIO/SpaCy_sm_BIO/LDSII_52_Kassow_OnegShabbes_text_conll_SpaCy_sm_BIO.txt
