# %%
# operation system
import os
# regular expression
import re
# retrives file support
import glob
# make a table
import pandas as pd
# regular expression
import re

#### HAND TEXT ####

# inform the path
for file_path in glob.iglob('hand_pandas/*txt'):
    #transform path into a readable file
    f_hand = (file_path)
    #print(f_hand)
    
    # open the variable to be read and split into words
    with open(f_hand, 'r', encoding='utf8') as f:
        # read and split into words to count word in file
        t_hand = f.read()
        #print(t_hand)

#### CLEAN TEXT ####

# inform the path
for f_path in glob.iglob('SpaCy_BIO/SpaCy_lg_BIO/*txt'):
    #transform path into a readable file
    f_clean = (f_path)
    #print(f_clean)
    
    # open the variable to be read and split into words
    with open(f_clean, 'r', encoding='utf8') as f_BIO:
        # read and split into words to count word in file
        t_clean = f_BIO.read()
        #print(t_clean) 
        
        #### PANDAS ####
        
        df_hand = pd.read_csv(f_hand, sep="\t", names=["TOK"])
        #print(df_clean)
        
        df_clean = pd.read_csv(f_clean, sep="\t", names=["TOKEN", "PREDICTION", "GOLD", "VALIDITY"])
        #print(df_hand)

        # convert the dictionary into DataFrame
        table_clean = pd.DataFrame(df_clean)
        #print(table_clean)
        table_hand = pd.DataFrame(df_hand)
        #print(table_hand)
        
        # split the column TOK in two GOLD with the IOB format and TOK_ with the tokenized text
        table_hand[['TOK_','GOLD_bio']] = table_hand.TOK.str.split(" ",expand=True,)

        #df['columnF'] = pd.Series(df1['columnF'])
        table_clean['GOLD']=pd.Series(table_hand['GOLD_bio'])

        # delete the index
        blankIndex=[''] * len(table_clean)
        table_clean.index=blankIndex

        # delete the column from TABLE_HAND previews columns
        del table_hand ['TOK']
        del table_hand ['TOK_']

        # it allows to display entire table
        pd.set_option("display.max_rows", None, "display.max_columns", None )

        # function to compare columns NE-COARSE-LIT x GOLD
        def compare(x):    
            return '1' if x['PREDICTION'] == x['GOLD'] else 'O'

        table_clean['VALIDITY'] = table_clean.apply(compare, axis=1)

        #print(table_hand)
        #print(table_clean)
      
        # directory out
        output_dir = "db_results/prediction_lg/"
        # new files out with original's name plus _text and its new format .txt
        results_file = "%s%s_prediction.tsv"%(output_dir, os.path.splitext(os.path.basename(f_clean))[0])
        print(results_file)
        # write to files
        with open(results_file,'w') as write_csv:
            write_csv.write(table_clean.to_csv(sep='\t', index=False))
            #print(write_csv)
# Out:
# db_results/prediction_lg/BNU_01_Didier_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_02_Colin_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_03_Jacob_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_04_Gfrereis_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_05_Dege_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_06_Therstappen_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_07_Jacob_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_08_PoncerGuedron_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_09_Jacob_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_10_Bon_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_11_Bert_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_12_Bigg_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_13_Mathis_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_14_Canfora_a_voir_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_15_Mohnike_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_16_Grage_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/BNU_17_Ochsner_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/CMA_11_2018_Calame_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg/CMA_11_2018_Dupont_text_SpaCy_lg_BIO_prediction.tsv
# db_results/prediction_lg